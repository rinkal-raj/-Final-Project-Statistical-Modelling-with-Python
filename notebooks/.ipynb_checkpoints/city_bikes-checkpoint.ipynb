# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
import requests
import json
import os

business_id = '4U9kSBLuBDU391x6bxU-YA'
api_key = os.environ["YELP_API_KEY"]
headers = {'Authorization': 'Bearer %s' % api_key}
#Define the end point URL for the milano city bike network
endpoint = 'https://api.yelp.com/v3/businesses/search'
params = {'term':'Restaurants','location':'London'}

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
req=requests.get(endpoint, params=params, headers=headers)
 # proceed only if the status code is 200
print('The status code is {}'.format(req.status_code)) 
# printing the text from the response 
restuarnt_details = json.loads(req.text)
restuarnt_details
# Out:
# The status code is 200
# {'businesses': [{'id': 'Vaq49W0ubGjuIc4h5_qQ0w',
#    'alias': 'the-mayfair-chippy-london-2',
#    'name': 'The Mayfair Chippy',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BDTRkfVSJ8hoAT0amAfwkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mayfair-chippy-london-2?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 394,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5131345, 'longitude': -0.1533961},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 North Audley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 6WE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 North Audley Street',
#      'London W1K 6WE',
#      'United Kingdom']},
#    'phone': '+442077412233',
#    'display_phone': '+44 20 7741 2233',
#    'distance': 1205.5379325772763},
#   {'id': 'oK_SLmmAVQg3meguh7LrIA',
#    'alias': 'dishoom-london',
#    'name': 'Dishoom',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LVjieHU8Rah9arssRqP47g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dishoom-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 2276,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512447030091, 'longitude': -0.1269579217873},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "12 Upper Saint Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9FB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["12 Upper Saint Martin's Lane",
#      'London WC2H 9FB',
#      'United Kingdom']},
#    'phone': '+442074209320',
#    'display_phone': '+44 20 7420 9320',
#    'distance': 626.5674318297622},
#   {'id': 'teXPunKtpwj0NuttvPYhyQ',
#    'alias': 'the-victoria-paddington',
#    'name': 'The Victoria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fXueWoi1k3Tztueo3wnN4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-victoria-paddington?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 263,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51350403679, 'longitude': -0.17119959969309},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10a Strathearn Place',
#     'address2': '',
#     'address3': '',
#     'city': 'Paddington',
#     'zip_code': 'W2 2NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10a Strathearn Place',
#      'Paddington W2 2NH',
#      'United Kingdom']},
#    'phone': '+442077241191',
#    'display_phone': '+44 20 7724 1191',
#    'distance': 2438.1572439509278},
#   {'id': 'qhbCUUn1CM27dvTPUwvAUA',
#    'alias': 'flat-iron-london-2',
#    'name': 'Flat Iron',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BawTx5b2LdfMVHfFDJUMzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flat-iron-london-2?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 454,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51212, 'longitude': -0.1384008},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17 Beak Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9RW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Beak Street',
#      'Soho',
#      'London W1F 9RW',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 186.27203865325515},
#   {'id': 'hOLFwKg4-0FsCleJ4yoCXw',
#    'alias': 'duck-and-waffle-london',
#    'name': 'Duck & Waffle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4uCfQ0ZnRnGa9cK9-LpX3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duck-and-waffle-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 841,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516178, 'longitude': -0.08094},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '110 Bishopsgate',
#     'address2': '40th Floor',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2N 4AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['110 Bishopsgate',
#      '40th Floor',
#      'London EC2N 4AY',
#      'United Kingdom']},
#    'phone': '+442036407310',
#    'display_phone': '+44 20 3640 7310',
#    'distance': 3825.569046751585},
#   {'id': 'KzYd2EaFvmu63wqTIektSA',
#    'alias': 'padella-london-3',
#    'name': 'Padella',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7Nzmy6o_KwF0nLM41S_kUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/padella-london-3?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 272,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5051451, 'longitude': -0.0899515},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Southwark Street',
#      'London SE1 1TQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3306.1684522874934},
#   {'id': 'b8u_D0Qlp0-nqSC6O2fMNw',
#    'alias': 'restaurant-gordon-ramsay-london-3',
#    'name': 'Restaurant Gordon Ramsay',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aF5kqFsGNKZm1M2BSXkMZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-gordon-ramsay-london-3?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 236,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.485833, 'longitude': -0.161966},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '68 Royal Hospital Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 4HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['68 Royal Hospital Road',
#      'London SW3 4HP',
#      'United Kingdom']},
#    'phone': '+442073524441',
#    'display_phone': '+44 20 7352 4441',
#    'distance': 3509.7496283842606},
#   {'id': 'Wjgxl0lSp_FRtzecbJ4FZQ',
#    'alias': 'the-queens-arms-london',
#    'name': 'The Queens Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-aZQ5ixyWyZxTIiSSgYPfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-queens-arms-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 163,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4925789, 'longitude': -0.1392194},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Warwick Way',
#     'address2': 'Pimlico',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Warwick Way',
#      'Pimlico',
#      'London SW1V 1QT',
#      'United Kingdom']},
#    'phone': '+442078343313',
#    'display_phone': '+44 20 7834 3313',
#    'distance': 2271.0625715098713},
#   {'id': '0B-ag3J18TatG9H9EQohGg',
#    'alias': 'hawksmoor-seven-dials-london-4',
#    'name': 'Hawksmoor Seven Dials',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lbFKecn94lG2Vd4UPeFYEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hawksmoor-seven-dials-london-4?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 376,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5134998914001,
#     'longitude': -0.12567396291297},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '11 Langley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Langley Street',
#      'London WC2H 9JG',
#      'United Kingdom']},
#    'phone': '+442074209390',
#    'display_phone': '+44 20 7420 9390',
#    'distance': 715.8050107104362},
#   {'id': 'L4QlWFPlkJVwDm5_jxt4og',
#    'alias': 'mercato-mayfair-london',
#    'name': 'Mercato Mayfair',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cRYYSmVQlFt5Jp7DmIkPxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mercato-mayfair-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 20,
#    'categories': [{'alias': 'popuprestaurants',
#      'title': 'Pop-Up Restaurants'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5130980394816,
#     'longitude': -0.153270626983613},
#    'transactions': [],
#    'location': {'address1': 'North Audley Street',
#     'address2': '',
#     'address3': "St Mark's Mayfair",
#     'city': 'London',
#     'zip_code': 'W1K 6WL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['North Audley Street',
#      "St Mark's Mayfair",
#      'London W1K 6WL',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1196.789048537776},
#   {'id': 'Z0r83lDOA1mI8RpNccXtHw',
#    'alias': 'the-fat-bear-london',
#    'name': 'The Fat Bear',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2ac6nNGBviKDuYYukDRmRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fat-bear-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 127,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5131833881734,
#     'longitude': -0.10138103121642},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Carter Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4V 5DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Carter Lane',
#      'London EC4V 5DY',
#      'United Kingdom']},
#    'phone': '+442072362498',
#    'display_phone': '+44 20 7236 2498',
#    'distance': 2394.295553294889},
#   {'id': 'tYynO1nOy1GKxMV3jkxbmw',
#    'alias': 'the-breakfast-club-london-2',
#    'name': 'The Breakfast Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TElKM303HWt3LAkvgBuTWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-club-london-2?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 551,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514733, 'longitude': -0.135406},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "33 D'Arblay Street",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["33 D'Arblay Street",
#      'London W1F 8EU',
#      'United Kingdom']},
#    'phone': '+442074342571',
#    'display_phone': '+44 20 7434 2571',
#    'distance': 202.48528573555356},
#   {'id': 'zJNI06Y2zZQFh9OBSFCdgQ',
#    'alias': 'sketch-london-2',
#    'name': 'Sketch',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jE0K_IohFjyvVnVY2EdFlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sketch-london-2?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 954,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5127614699071,
#     'longitude': -0.14159163911048},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '9 Conduit Street',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2XG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Conduit Street',
#      'Mayfair',
#      'London W1S 2XG',
#      'United Kingdom']},
#    'phone': '+442076594500',
#    'display_phone': '+44 20 7659 4500',
#    'distance': 388.9437191578902},
#   {'id': 'IBV7BsXnv2gX68nWUARhjw',
#    'alias': 'mother-mash-london',
#    'name': 'Mother Mash',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oOiLc_8eHgI2ouwzonR5yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mother-mash-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 510,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512935, 'longitude': -0.139414},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '26 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7QZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Ganton Street',
#      'London W1F 7QZ',
#      'United Kingdom']},
#    'phone': '+442074949644',
#    'display_phone': '+44 20 7494 9644',
#    'distance': 233.42239569404654},
#   {'id': 'lg0ZQJDQeHN_5Ela7ypyiw',
#    'alias': 'the-golden-chippy-london',
#    'name': 'The Golden Chippy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bkFPTIbhVCB1LzlwmCwXzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-golden-chippy-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 141,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.475864, 'longitude': -0.018518},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '62 Greenwich High Road',
#     'address2': 'Greenwich',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE10 8LF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['62 Greenwich High Road',
#      'Greenwich',
#      'London SE10 8LF',
#      'United Kingdom']},
#    'phone': '+442086924333',
#    'display_phone': '+44 20 8692 4333',
#    'distance': 9116.786047289621},
#   {'id': 'a4FkZ2b7Wn3-AP7q3ptHtQ',
#    'alias': 'duck-and-waffle-local-london',
#    'name': 'Duck & Waffle Local',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1x4I2Yy_waGhbs8MKn_KUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duck-and-waffle-local-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 146,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'waffles', 'title': 'Waffles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5094175706263,
#     'longitude': -0.132749820495633},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '52 Haymarket',
#     'address2': "St James's Market",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Haymarket',
#      "St James's Market",
#      'London SW1Y 4RP',
#      'United Kingdom']},
#    'phone': '+442039004444',
#    'display_phone': '+44 20 3900 4444',
#    'distance': 450.4935927796803},
#   {'id': 'mc1KLbA1Sy4kUTKo0ZEeRQ',
#    'alias': 'dishoom-london-7',
#    'name': 'Dishoom',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bnu8b8OxipYI_mNA0a5_PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dishoom-london-7?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 645,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513087, 'longitude': -0.139767},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Kingly Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Kingly Street',
#      'London W1B 5QP',
#      'United Kingdom']},
#    'phone': '+442074209322',
#    'display_phone': '+44 20 7420 9322',
#    'distance': 262.7329356516094},
#   {'id': 'bJiVADMSTEKj0MjqiLrOPA',
#    'alias': 'the-grazing-goat-marylebone-london',
#    'name': 'The Grazing Goat Marylebone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/h73f5PAFit9wdm8w_zm3lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grazing-goat-marylebone-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 274,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515378341447,
#     'longitude': -0.15823586449841},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 New Quebec Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7RQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 New Quebec Street',
#      'London W1H 7RQ',
#      'United Kingdom']},
#    'phone': '+442077247243',
#    'display_phone': '+44 20 7724 7243',
#    'distance': 1563.9775349708373},
#   {'id': 'Rb3xF0gkAwnDHML6okB1FA',
#    'alias': 'honey-and-co-london',
#    'name': 'Honey & Co',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GjRuBFxsvAvRsNXS44S23Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/honey-and-co-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 117,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5238287, 'longitude': -0.1407882},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '25a Warren Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 5LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25a Warren Street',
#      'London W1T 5LZ',
#      'United Kingdom']},
#    'phone': '+442073886175',
#    'display_phone': '+44 20 7388 6175',
#    'distance': 1256.142106360687},
#   {'id': 'ggwDV5tRXMfQJvH2-yZVug',
#    'alias': 'the-barbary-london',
#    'name': 'The Barbary',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/I0CErDtzCzpDfsP17n82sw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-barbary-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 87,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.5144480132327,
#     'longitude': -0.126241173962971},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': "16 Neal's Yard",
#     'address2': 'Seven Dials',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'WC2H 9DP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["16 Neal's Yard",
#      'Seven Dials',
#      'London WC2H 9DP',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 694.4603216887577}],
#  'total': 13300,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
import pandas as pd
# Use json_normalize() to convert JSON to DataFrame
dict = restuarnt_details
df2 = pd.json_normalize(dict['businesses']) 
df2
# Out:
#                         id                               alias  \
# 0   Vaq49W0ubGjuIc4h5_qQ0w         the-mayfair-chippy-london-2
# 1   oK_SLmmAVQg3meguh7LrIA                      dishoom-london
# 2   teXPunKtpwj0NuttvPYhyQ             the-victoria-paddington
# 3   qhbCUUn1CM27dvTPUwvAUA                  flat-iron-london-2
# 4   hOLFwKg4-0FsCleJ4yoCXw              duck-and-waffle-london
# 5   KzYd2EaFvmu63wqTIektSA                    padella-london-3
# 6   b8u_D0Qlp0-nqSC6O2fMNw   restaurant-gordon-ramsay-london-3
# 7   Wjgxl0lSp_FRtzecbJ4FZQ              the-queens-arms-london
# 8   0B-ag3J18TatG9H9EQohGg      hawksmoor-seven-dials-london-4
# 9   L4QlWFPlkJVwDm5_jxt4og              mercato-mayfair-london
# 10  Z0r83lDOA1mI8RpNccXtHw                 the-fat-bear-london
# 11  tYynO1nOy1GKxMV3jkxbmw         the-breakfast-club-london-2
# 12  zJNI06Y2zZQFh9OBSFCdgQ                     sketch-london-2
# 13  IBV7BsXnv2gX68nWUARhjw                  mother-mash-london
# 14  lg0ZQJDQeHN_5Ela7ypyiw            the-golden-chippy-london
# 15  a4FkZ2b7Wn3-AP7q3ptHtQ        duck-and-waffle-local-london
# 16  mc1KLbA1Sy4kUTKo0ZEeRQ                    dishoom-london-7
# 17  bJiVADMSTEKj0MjqiLrOPA  the-grazing-goat-marylebone-london
# 18  Rb3xF0gkAwnDHML6okB1FA                 honey-and-co-london
# 19  ggwDV5tRXMfQJvH2-yZVug                  the-barbary-london
#
#                            name  \
# 0            The Mayfair Chippy
# 1                       Dishoom
# 2                  The Victoria
# 3                     Flat Iron
# 4                 Duck & Waffle
# 5                       Padella
# 6      Restaurant Gordon Ramsay
# 7               The Queens Arms
# 8         Hawksmoor Seven Dials
# 9               Mercato Mayfair
# 10                 The Fat Bear
# 11           The Breakfast Club
# 12                       Sketch
# 13                  Mother Mash
# 14            The Golden Chippy
# 15          Duck & Waffle Local
# 16                      Dishoom
# 17  The Grazing Goat Marylebone
# 18                   Honey & Co
# 19                  The Barbary
#
#                                             image_url  is_closed  \
# 0   https://s3-media4.fl.yelpcdn.com/bphoto/BDTRkf...      False
# 1   https://s3-media3.fl.yelpcdn.com/bphoto/LVjieH...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/fXueWo...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/BawTx5...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/4uCfQ0...      False
# 5   https://s3-media1.fl.yelpcdn.com/bphoto/7Nzmy6...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/aF5kqF...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/-aZQ5i...      False
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/lbFKec...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/cRYYSm...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/2ac6nN...      False
# 11  https://s3-media3.fl.yelpcdn.com/bphoto/TElKM3...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/jE0K_I...      False
# 13  https://s3-media1.fl.yelpcdn.com/bphoto/oOiLc_...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/bkFPTI...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/1x4I2Y...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/bnu8b8...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/h73f5P...      False
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/GjRuBF...      False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/I0CErD...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/the-mayfair-chippy-lo...           394
# 1   https://www.yelp.com/biz/dishoom-london?adjust...          2276
# 2   https://www.yelp.com/biz/the-victoria-paddingt...           263
# 3   https://www.yelp.com/biz/flat-iron-london-2?ad...           454
# 4   https://www.yelp.com/biz/duck-and-waffle-londo...           841
# 5   https://www.yelp.com/biz/padella-london-3?adju...           272
# 6   https://www.yelp.com/biz/restaurant-gordon-ram...           236
# 7   https://www.yelp.com/biz/the-queens-arms-londo...           163
# 8   https://www.yelp.com/biz/hawksmoor-seven-dials...           376
# 9   https://www.yelp.com/biz/mercato-mayfair-londo...            20
# 10  https://www.yelp.com/biz/the-fat-bear-london?a...           127
# 11  https://www.yelp.com/biz/the-breakfast-club-lo...           551
# 12  https://www.yelp.com/biz/sketch-london-2?adjus...           954
# 13  https://www.yelp.com/biz/mother-mash-london?ad...           510
# 14  https://www.yelp.com/biz/the-golden-chippy-lon...           141
# 15  https://www.yelp.com/biz/duck-and-waffle-local...           146
# 16  https://www.yelp.com/biz/dishoom-london-7?adju...           645
# 17  https://www.yelp.com/biz/the-grazing-goat-mary...           274
# 18  https://www.yelp.com/biz/honey-and-co-london?a...           117
# 19  https://www.yelp.com/biz/the-barbary-london?ad...            87
#
#                                            categories  rating transactions  \
# 0   [{'alias': 'fishnchips', 'title': 'Fish & Chip...     4.5           []
# 1            [{'alias': 'indpak', 'title': 'Indian'}]     4.5           []
# 2   [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     4.5           []
# 3        [{'alias': 'steak', 'title': 'Steakhouses'}]     4.5           []
# 4   [{'alias': 'modern_european', 'title': 'Modern...     4.0           []
# 5          [{'alias': 'italian', 'title': 'Italian'}]     4.5           []
# 6   [{'alias': 'french', 'title': 'French'}, {'ali...     4.5           []
# 7   [{'alias': 'british', 'title': 'British'}, {'a...     4.5           []
# 8   [{'alias': 'british', 'title': 'British'}, {'a...     4.5           []
# 9   [{'alias': 'popuprestaurants', 'title': 'Pop-U...     4.5           []
# 10  [{'alias': 'tradamerican', 'title': 'American ...     4.5           []
# 11  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0           []
# 12  [{'alias': 'french', 'title': 'French'}, {'ali...     4.0           []
# 13         [{'alias': 'british', 'title': 'British'}]     4.0           []
# 14  [{'alias': 'fishnchips', 'title': 'Fish & Chip...     5.0           []
# 15  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...     4.5           []
# 16           [{'alias': 'indpak', 'title': 'Indian'}]     4.5           []
# 17  [{'alias': 'gastropubs', 'title': 'Gastropubs'...     4.0           []
# 18  [{'alias': 'mideastern', 'title': 'Middle East...     4.5           []
# 19  [{'alias': 'mideastern', 'title': 'Middle East...     5.0           []
#
#     ... coordinates.latitude coordinates.longitude  \
# 0   ...            51.513134             -0.153396
# 1   ...            51.512447             -0.126958
# 2   ...            51.513504             -0.171200
# 3   ...            51.512120             -0.138401
# 4   ...            51.516178             -0.080940
# 5   ...            51.505145             -0.089952
# 6   ...            51.485833             -0.161966
# 7   ...            51.492579             -0.139219
# 8   ...            51.513500             -0.125674
# 9   ...            51.513098             -0.153271
# 10  ...            51.513183             -0.101381
# 11  ...            51.514733             -0.135406
# 12  ...            51.512761             -0.141592
# 13  ...            51.512935             -0.139414
# 14  ...            51.475864             -0.018518
# 15  ...            51.509418             -0.132750
# 16  ...            51.513087             -0.139767
# 17  ...            51.515378             -0.158236
# 18  ...            51.523829             -0.140788
# 19  ...            51.514448             -0.126241
#
#                location.address1  location.address2  location.address3  \
# 0         14 North Audley Street
# 1   12 Upper Saint Martin's Lane
# 2           10a Strathearn Place
# 3                 17 Beak Street               Soho
# 4                110 Bishopsgate         40th Floor
# 5             6 Southwark Street
# 6         68 Royal Hospital Road
# 7                 11 Warwick Way            Pimlico
# 8              11 Langley Street
# 9            North Audley Street                     St Mark's Mayfair
# 10                61 Carter Lane
# 11            33 D'Arblay Street
# 12              9 Conduit Street            Mayfair
# 13              26 Ganton Street
# 14        62 Greenwich High Road          Greenwich               None
# 15                  52 Haymarket  St James's Market
# 16              22 Kingly Street               None
# 17           6 New Quebec Street
# 18             25a Warren Street
# 19                16 Neal's Yard        Seven Dials               None
#
#     location.city location.zip_code location.country location.state  \
# 0          London           W1K 6WE               GB            XGL
# 1          London          WC2H 9FB               GB            XGL
# 2      Paddington            W2 2NH               GB            XGL
# 3          London           W1F 9RW               GB            XGL
# 4          London          EC2N 4AY               GB            XGL
# 5          London           SE1 1TQ               GB            XGL
# 6          London           SW3 4HP               GB            XGL
# 7          London          SW1V 1QT               GB            XGL
# 8          London          WC2H 9JG               GB            XGL
# 9          London           W1K 6WL               GB            XGL
# 10         London          EC4V 5DY               GB            XGL
# 11         London           W1F 8EU               GB            XGL
# 12         London           W1S 2XG               GB            XGL
# 13         London           W1F 7QZ               GB            XGL
# 14         London          SE10 8LF               GB            XGL
# 15         London          SW1Y 4RP               GB            XGL
# 16         London           W1B 5QP               GB            XGL
# 17         London           W1H 7RQ               GB            XGL
# 18         London           W1T 5LZ               GB            XGL
# 19         London          WC2H 9DP               GB            XGL
#
#                              location.display_address
# 0   [14 North Audley Street, London W1K 6WE, Unite...
# 1   [12 Upper Saint Martin's Lane, London WC2H 9FB...
# 2   [10a Strathearn Place, Paddington W2 2NH, Unit...
# 3   [17 Beak Street, Soho, London W1F 9RW, United ...
# 4   [110 Bishopsgate, 40th Floor, London EC2N 4AY,...
# 5   [6 Southwark Street, London SE1 1TQ, United Ki...
# 6   [68 Royal Hospital Road, London SW3 4HP, Unite...
# 7   [11 Warwick Way, Pimlico, London SW1V 1QT, Uni...
# 8   [11 Langley Street, London WC2H 9JG, United Ki...
# 9   [North Audley Street, St Mark's Mayfair, Londo...
# 10  [61 Carter Lane, London EC4V 5DY, United Kingdom]
# 11  [33 D'Arblay Street, London W1F 8EU, United Ki...
# 12  [9 Conduit Street, Mayfair, London W1S 2XG, Un...
# 13  [26 Ganton Street, London W1F 7QZ, United King...
# 14  [62 Greenwich High Road, Greenwich, London SE1...
# 15  [52 Haymarket, St James's Market, London SW1Y ...
# 16  [22 Kingly Street, London W1B 5QP, United King...
# 17  [6 New Quebec Street, London W1H 7RQ, United K...
# 18  [25a Warren Street, London W1T 5LZ, United Kin...
# 19  [16 Neal's Yard, Seven Dials, London WC2H 9DP,...
#
# [20 rows x 24 columns]

# %%
restaurant_data = pd.DataFrame(df2, columns = ['name','review_count','location.address1','rating'])
restaurant_data
# Out:
#                            name  review_count             location.address1  \
# 0            The Mayfair Chippy           394        14 North Audley Street
# 1                       Dishoom          2276  12 Upper Saint Martin's Lane
# 2                  The Victoria           263          10a Strathearn Place
# 3                     Flat Iron           454                17 Beak Street
# 4                 Duck & Waffle           841               110 Bishopsgate
# 5                       Padella           272            6 Southwark Street
# 6      Restaurant Gordon Ramsay           236        68 Royal Hospital Road
# 7               The Queens Arms           163                11 Warwick Way
# 8         Hawksmoor Seven Dials           376             11 Langley Street
# 9               Mercato Mayfair            20           North Audley Street
# 10                 The Fat Bear           127                61 Carter Lane
# 11           The Breakfast Club           551            33 D'Arblay Street
# 12                       Sketch           954              9 Conduit Street
# 13                  Mother Mash           510              26 Ganton Street
# 14            The Golden Chippy           141        62 Greenwich High Road
# 15          Duck & Waffle Local           146                  52 Haymarket
# 16                      Dishoom           645              22 Kingly Street
# 17  The Grazing Goat Marylebone           274           6 New Quebec Street
# 18                   Honey & Co           117             25a Warren Street
# 19                  The Barbary            87                16 Neal's Yard
#
#     rating
# 0      4.5
# 1      4.5
# 2      4.5
# 3      4.5
# 4      4.0
# 5      4.5
# 6      4.5
# 7      4.5
# 8      4.5
# 9      4.5
# 10     4.5
# 11     4.0
# 12     4.0
# 13     4.0
# 14     5.0
# 15     4.5
# 16     4.5
# 17     4.0
# 18     4.5
# 19     5.0
