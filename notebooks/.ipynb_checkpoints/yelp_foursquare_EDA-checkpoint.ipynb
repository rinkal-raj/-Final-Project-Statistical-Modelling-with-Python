# %%
import requests
import json
import os
import pandas as pd

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
api_key = os.environ["FOURSQUARE_API_KEY"]
url = "https://api.foursquare.com/v3/places/search?query=bike%20station&ll=51.50%2C-0.127&radius=1000"
# Create dictionary for headers
headers = {"Accept": "application/json"}
# Add key with our API KEY
headers['Authorization'] = api_key
result = requests.get(url,headers=headers)
# proceed only if the status code is 200
print('The status code is {}'.format(result.status_code)) 
# printing the text from the response 
foursquare_bike = json.loads(result.text)
foursquare_bike
# Out:
# The status code is 200
# {'results': [{'fsq_id': '4ae9970cf964a5203bb521e3',
#    'categories': [{'id': 19000,
#      'name': 'Travel and Transportation',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 183,
#    'geocodes': {'main': {'latitude': 51.50111, 'longitude': -0.125039},
#     'roof': {'latitude': 51.50111, 'longitude': -0.125039}},
#    'link': '/v3/places/4ae9970cf964a5203bb521e3',
#    'location': {'address': 'Bridge St',
#     'admin_region': 'England',
#     'country': 'GB',
#     'cross_street': '',
#     'formatted_address': 'Bridge St, London, Greater London, SW1A 2PW',
#     'locality': 'London',
#     'post_town': 'London',
#     'postcode': 'SW1A 2PW',
#     'region': 'Greater London'},
#    'name': 'Westminster London Underground Station',
#    'related_places': {'children': [{'fsq_id': '58e384f0876ade3d250c37b7',
#       'name': 'Cards Galore'},
#      {'fsq_id': '4fec74363d7c9b9c78e06943', 'name': 'WHSmith'},
#      {'fsq_id': '5b48969816fa04002c2f6961', 'name': 'Greggs'}]},
#    'timezone': 'Europe/London'},
#   {'fsq_id': '51221e27e4b0320fabfb84c8',
#    'categories': [{'id': 19043,
#      'name': 'Bus Stop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 184,
#    'geocodes': {'main': {'latitude': 51.501119, 'longitude': -0.124851},
#     'roof': {'latitude': 51.501119, 'longitude': -0.124851}},
#    'link': '/v3/places/51221e27e4b0320fabfb84c8',
#    'location': {'country': 'GB', 'cross_street': '', 'formatted_address': ''},
#    'name': 'Westminster Station Parliament Square bus stop',
#    'related_places': {},
#    'timezone': 'Europe/London'},
#   {'fsq_id': '58deeb35876ade1790d11ef8',
#    'categories': [{'id': 19043,
#      'name': 'Bus Stop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 281,
#    'geocodes': {'drop_off': {'latitude': 51.502437, 'longitude': -0.125985},
#     'main': {'latitude': 51.502428, 'longitude': -0.125795},
#     'roof': {'latitude': 51.502428, 'longitude': -0.125795}},
#    'link': '/v3/places/58deeb35876ade1790d11ef8',
#    'location': {'address': '53 Parliament St',
#     'admin_region': 'England',
#     'country': 'GB',
#     'cross_street': '',
#     'formatted_address': '53 Parliament St, London, Greater London, SW1A 2NH',
#     'locality': 'London',
#     'post_town': 'London',
#     'postcode': 'SW1A 2NH',
#     'region': 'Greater London'},
#    'name': 'Bus Stop F - Westminster Station',
#    'related_places': {},
#    'timezone': 'Europe/London'},
#   {'fsq_id': '5036b36dcc6417d4bcd9a24b',
#    'categories': [{'id': 19000,
#      'name': 'Travel and Transportation',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 498,
#    'geocodes': {'main': {'latitude': 51.499823, 'longitude': -0.134154},
#     'roof': {'latitude': 51.499823, 'longitude': -0.134154}},
#    'link': '/v3/places/5036b36dcc6417d4bcd9a24b',
#    'location': {'address': 'Palmer St 11',
#     'admin_region': 'England',
#     'country': 'GB',
#     'formatted_address': 'Palmer St 11, London, Greater London, SW1H 0BD',
#     'locality': 'London',
#     'post_town': 'London',
#     'postcode': 'SW1H 0BD',
#     'region': 'Greater London'},
#    'name': "St. James's Park London Underground Station",
#    'related_places': {'children': [{'fsq_id': '5c62c4c506fb60002c78821c',
#       'name': 'Foreign Payments'},
#      {'fsq_id': '4b6044cbf964a520d5dc29e3', 'name': 'Caffe Grana'},
#      {'fsq_id': '594e69450336931c7f92ce75',
#       'name': "London-Tokyo Property Services St. James's Park Branch"},
#      {'fsq_id': '5c0f774f6f0aa2002c8cbdda', 'name': 'WHSmith'},
#      {'fsq_id': '564c749d498ec148d8e4e11b', 'name': 'SimplyFresh'}]},
#    'timezone': 'Europe/London'},
#   {'fsq_id': '0d11101ea43b4a8c1479a6fe',
#    'categories': [{'id': 19047,
#      'name': 'Rail Station',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 200,
#    'geocodes': {'main': {'latitude': 51.501226, 'longitude': -0.124878},
#     'roof': {'latitude': 51.501226, 'longitude': -0.124878}},
#    'link': '/v3/places/0d11101ea43b4a8c1479a6fe',
#    'location': {'address': 'Bridge St',
#     'admin_region': 'England',
#     'country': 'GB',
#     'formatted_address': 'Bridge St, London, SW1A 2JR',
#     'locality': 'London',
#     'post_town': 'London',
#     'postcode': 'SW1A 2JR'},
#    'name': 'Westminster Tube Station',
#    'related_places': {}},
#   {'fsq_id': 'b8c4f6db7692490458febd99',
#    'categories': [],
#    'chains': [],
#    'distance': 219,
#    'geocodes': {'drop_off': {'latitude': 51.500657, 'longitude': -0.130016},
#     'main': {'latitude': 51.50061, 'longitude': -0.130013},
#     'roof': {'latitude': 51.50061, 'longitude': -0.130013}},
#    'link': '/v3/places/b8c4f6db7692490458febd99',
#    'location': {'address': '6 Lewisham St',
#     'admin_region': 'England',
#     'country': 'GB',
#     'formatted_address': '6 Lewisham St, London, SW1H 9AH',
#     'locality': 'London',
#     'post_town': 'London',
#     'postcode': 'SW1H 9AH'},
#    'name': 'Cooper Bike Company Limited',
#    'related_places': {}},
#   {'fsq_id': '612a32746f490c66a4bd3de5',
#    'categories': [{'id': 19043,
#      'name': 'Bus Stop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 579,
#    'geocodes': {'main': {'latitude': 51.497588, 'longitude': -0.134504},
#     'roof': {'latitude': 51.497588, 'longitude': -0.134504}},
#    'link': '/v3/places/612a32746f490c66a4bd3de5',
#    'location': {'admin_region': 'England',
#     'country': 'GB',
#     'cross_street': '',
#     'formatted_address': 'London, SW1H 0XA',
#     'locality': 'London',
#     'post_town': 'London',
#     'postcode': 'SW1H 0XA'},
#    'name': "St James's Park Station Bus Stop Sc",
#    'related_places': {},
#    'timezone': 'Europe/London'},
#   {'fsq_id': '4f8e776ae5e8319783a21dd1',
#    'categories': [{'id': 19029,
#      'name': 'Tour Provider',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 744,
#    'geocodes': {'main': {'latitude': 51.501353, 'longitude': -0.116286},
#     'roof': {'latitude': 51.501353, 'longitude': -0.116286}},
#    'link': '/v3/places/4f8e776ae5e8319783a21dd1',
#    'location': {'address': '2 Addington St',
#     'admin_region': 'England',
#     'country': 'GB',
#     'formatted_address': '2 Addington St, London, Greater London, SE1 7RY',
#     'locality': 'London',
#     'post_town': 'London',
#     'postcode': 'SE1 7RY',
#     'region': 'Greater London'},
#    'name': 'Brakeaway Bike Tours',
#    'related_places': {},
#    'timezone': 'Europe/London'},
#   {'fsq_id': '5e3ae2ea2a11f800087464d8',
#    'categories': [{'id': 19043,
#      'name': 'Bus Stop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 852,
#    'geocodes': {'main': {'latitude': 51.503266, 'longitude': -0.115855},
#     'roof': {'latitude': 51.503266, 'longitude': -0.115855}},
#    'link': '/v3/places/5e3ae2ea2a11f800087464d8',
#    'location': {'admin_region': 'England',
#     'country': 'GB',
#     'cross_street': '',
#     'formatted_address': 'London, SE1 7NJ',
#     'locality': 'London',
#     'post_town': 'London',
#     'postcode': 'SE1 7NJ'},
#    'name': 'Waterloo Rail Station Bus Stop 17',
#    'related_places': {},
#    'timezone': 'Europe/London'},
#   {'fsq_id': '4bfd71712b83b713bbb7a998',
#    'categories': [{'id': 19047,
#      'name': 'Rail Station',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/trainstation_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 858,
#    'geocodes': {'main': {'latitude': 51.507926, 'longitude': -0.127398},
#     'roof': {'latitude': 51.507926, 'longitude': -0.127398}},
#    'link': '/v3/places/4bfd71712b83b713bbb7a998',
#    'location': {'address': 'Trafalgar Square',
#     'admin_region': 'England',
#     'country': 'GB',
#     'cross_street': 'at Strand',
#     'formatted_address': 'Trafalgar Square (at Strand), London, Greater London, WC2N 5DN',
#     'locality': 'London',
#     'post_town': 'London',
#     'postcode': 'WC2N 5DN',
#     'region': 'Greater London'},
#    'name': 'Charing Cross Underground Station',
#    'related_places': {'children': [{'fsq_id': '570a7a02498e9e882ebfbcab',
#       'name': 'Hidden London Charing Cross'},
#      {'fsq_id': '58c9317b15fb43576c0dc5d7', 'name': 'Donaldk Franchise'}]},
#    'timezone': 'Europe/London'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 51.5,
#      'longitude': -0.127},
#     'radius': 1000}}}}

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
api_key = os.environ["FOURSQUARE_API_KEY"]
params = {'term':'park','location':'= Chicago'}
#Define the end point URL for the milano city bike network
endpoint = "https://api.foursquare.com/v3/places/search?ll=41.8781136,-87.6297982"
# Create dictionary for headers
headers = {"Accept": "application/json"}
# Add key with our API KEY
headers['Authorization'] = api_key
result = requests.get(endpoint,params=params, headers=headers)
# proceed only if the status code is 200
print('The status code is {}'.format(result.status_code)) 
# printing the text from the response 
foursquare_park = json.loads(result.text)
foursquare_park
# Out:
# The status code is 200
# {'results': [{'fsq_id': '4adfca6df964a520777d21e3',
#    'categories': [{'id': 10039,
#      'name': 'Music Venue',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 442,
#    'geocodes': {'main': {'latitude': 41.878898, 'longitude': -87.624815},
#     'roof': {'latitude': 41.878898, 'longitude': -87.624815}},
#    'link': '/v3/places/4adfca6df964a520777d21e3',
#    'location': {'address': '220 S Michigan Ave',
#     'address_extended': 'Fl 8',
#     'census_block': '170313204001017',
#     'country': 'US',
#     'cross_street': 'btwn Adams & Jackson',
#     'dma': 'Chicago',
#     'formatted_address': '220 S Michigan Ave (btwn Adams & Jackson), Chicago, IL 60604',
#     'locality': 'Chicago',
#     'postcode': '60604',
#     'region': 'IL'},
#    'name': 'Symphony Center (Chicago Symphony Orchestra)',
#    'related_places': {'children': [{'fsq_id': '5d8136d5adf8620008fd8200',
#       'name': 'Opus Restaurant & Cafe'},
#      {'fsq_id': '4bbf6e6598f495214ea7d263',
#       'name': 'Symphony Center E&A Building'}]},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '49e9ef74f964a52011661fe3',
#    'categories': [{'id': 10027,
#      'name': 'Museum',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 526,
#    'geocodes': {'main': {'latitude': 41.879454, 'longitude': -87.623691},
#     'roof': {'latitude': 41.879454, 'longitude': -87.623691}},
#    'link': '/v3/places/49e9ef74f964a52011661fe3',
#    'location': {'address': '111 S Michigan Ave',
#     'address_extended': 'Ste 425',
#     'census_block': '170313204001005',
#     'country': 'US',
#     'cross_street': 'btwn Monroe St & Jackson Dr',
#     'dma': 'Chicago',
#     'formatted_address': '111 S Michigan Ave (btwn Monroe St & Jackson Dr), Chicago, IL 60603',
#     'locality': 'Chicago',
#     'postcode': '60603',
#     'region': 'IL'},
#    'name': 'The Art Institute of Chicago',
#    'related_places': {'children': [{'fsq_id': '56f80be2cd104c9189b44b4c',
#       'name': 'Art Institute Museum Cafe'},
#      {'fsq_id': '4dcd809cd164679b8ce8159e', 'name': 'The South Garden'},
#      {'fsq_id': '51326a18e4b0c9fcd5ebcbe8',
#       'name': 'The Museum Shop The Art Institute Of Chicago Chicago'},
#      {'fsq_id': '4bc9e614fb84c9b666d61b3e', 'name': 'Thorne Miniature Rooms'},
#      {'fsq_id': '537ce8d8498e9239c522798c', 'name': 'Fullerton Hall'},
#      {'fsq_id': '4bbfb622461576b0ea0d7932', 'name': "Members' Lounge"},
#      {'fsq_id': '4fbfb68ae4b00dd50dc5d4ca', 'name': 'Lichtenstein Exhibit'},
#      {'fsq_id': '4d408eefaae1b1f7e6fd87f5', 'name': 'Caffe Moderno'},
#      {'fsq_id': '60299c94476c2c7075864da7', 'name': 'Modern Art'},
#      {'fsq_id': '4fedf44be4b0660371b59ee2', 'name': 'The Modern Shop'},
#      {'fsq_id': '4c923ca9ae45224b2e6fee97',
#       'name': 'Carl Milles Sculpture - McKinlock Court'},
#      {'fsq_id': '4cfe602dc671721e12cdd218',
#       'name': 'Ferguson Administrative Wing'},
#      {'fsq_id': '602990c54e18a37e8995a370', 'name': 'American Art'},
#      {'fsq_id': '4bdb2a9e63c5c9b623a72668',
#       'name': 'Sculpture Garden - Art Institute of Chicago'},
#      {'fsq_id': '4c76bc6793faa093bf9aeefb', 'name': 'North Garden'},
#      {'fsq_id': '518f06ba498e20470ff4efdc',
#       'name': 'Ryerson & Burnham Libraries, The Art Institute of Chicago'},
#      {'fsq_id': '4fe1e073e4b0f27f2832fcd1',
#       'name': 'Art Institute Of Chicago Administrative Offices'},
#      {'fsq_id': '4c38f6c8dfb0e21e8ea3afa8', 'name': 'The Modern Wing'},
#      {'fsq_id': '6029a4b4476c2c7075963f16', 'name': 'Bisa Butler: Portraits'},
#      {'fsq_id': '4c4b4c389c8d2d7fa3f6c56a',
#       'name': 'Stock Exchange Trading Room'}]},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '4ae786a5f964a52019ac21e3',
#    'categories': [{'id': 10039,
#      'name': 'Music Venue',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#       'suffix': '.png'}},
#     {'id': 10043,
#      'name': 'Theater',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 436,
#    'geocodes': {'main': {'latitude': 41.875859, 'longitude': -87.625374},
#     'roof': {'latitude': 41.875859, 'longitude': -87.625374}},
#    'link': '/v3/places/4ae786a5f964a52019ac21e3',
#    'location': {'address': '50 E Ida B Wells Dr',
#     'census_block': '170313204001029',
#     'country': 'US',
#     'cross_street': 'Roosevelt University',
#     'dma': 'Chicago',
#     'formatted_address': '50 E Ida B Wells Dr (Roosevelt University), Chicago, IL 60605',
#     'locality': 'Chicago',
#     'postcode': '60605',
#     'region': 'IL'},
#    'name': 'Auditorium Theatre',
#    'related_places': {'parent': {'fsq_id': '49edc2d4f964a520f4671fe3',
#      'name': 'Roosevelt University'},
#     'children': [{'fsq_id': '4a751cf5f964a52093e01fe3',
#       'name': 'Willow Chicago'}]},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '4af4a50af964a5209df421e3',
#    'categories': [{'id': 17134,
#      'name': 'Tobacco Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tobacco_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 490,
#    'geocodes': {'main': {'latitude': 41.881635, 'longitude': -87.625918},
#     'roof': {'latitude': 41.881635, 'longitude': -87.625918}},
#    'link': '/v3/places/4af4a50af964a5209df421e3',
#    'location': {'address': '19 S Wabash Ave',
#     'address_extended': 'Fl 2',
#     'census_block': '170313204001008',
#     'country': 'US',
#     'cross_street': 'btwn E Madison St & E Monroe St',
#     'dma': 'Chicago',
#     'formatted_address': '19 S Wabash Ave (btwn E Madison St & E Monroe St), Chicago, IL 60603',
#     'locality': 'Chicago',
#     'postcode': '60603',
#     'region': 'IL'},
#    'name': 'Iwan Ries & Co.',
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '4b284c70f964a5202f9224e3',
#    'categories': [{'id': 10039,
#      'name': 'Music Venue',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 710,
#    'geocodes': {'main': {'latitude': 41.884275, 'longitude': -87.632958},
#     'roof': {'latitude': 41.884275, 'longitude': -87.632958}},
#    'link': '/v3/places/4b284c70f964a5202f9224e3',
#    'location': {'address': '151 W Randolph St',
#     'census_block': '170318391001040',
#     'country': 'US',
#     'cross_street': 'at LaSalle St',
#     'dma': 'Chicago',
#     'formatted_address': '151 W Randolph St (at LaSalle St), Chicago, IL 60603',
#     'locality': 'Chicago',
#     'postcode': '60603',
#     'region': 'IL'},
#    'name': 'Cadillac Palace Theatre',
#    'related_places': {},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '4a7ccf53f964a520b8ed1fe3',
#    'categories': [{'id': 10000,
#      'name': 'Arts and Entertainment',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 704,
#    'geocodes': {'main': {'latitude': 41.884542, 'longitude': -87.62879}},
#    'link': '/v3/places/4a7ccf53f964a520b8ed1fe3',
#    'location': {'address': '24 W Randolph St',
#     'census_block': '170318391001044',
#     'country': 'US',
#     'cross_street': 'btwn State St & Dearborn St',
#     'dma': 'Chicago',
#     'formatted_address': '24 W Randolph St (btwn State St & Dearborn St), Chicago, IL 60601',
#     'locality': 'Chicago',
#     'postcode': '60601',
#     'region': 'IL'},
#    'name': 'James M. Nederlander Theatre',
#    'related_places': {'children': [{'fsq_id': '62352bd3cea02e4a73aef91d',
#       'name': 'Moulin Rouge'}]},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '4b0850dff964a520da0823e3',
#    'categories': [{'id': 16007,
#      'name': 'Building / Structure',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 737,
#    'geocodes': {'main': {'latitude': 41.882621, 'longitude': -87.623401},
#     'roof': {'latitude': 41.882621, 'longitude': -87.623401}},
#    'link': '/v3/places/4b0850dff964a520da0823e3',
#    'location': {'address': '201 E Randolph St',
#     'census_block': '170313201022004',
#     'country': 'US',
#     'cross_street': 'btwn Randolph St & Monroe Dr',
#     'dma': 'Chicago',
#     'formatted_address': '201 E Randolph St (btwn Randolph St & Monroe Dr), Chicago, IL 60602',
#     'locality': 'Chicago',
#     'postcode': '60602',
#     'region': 'IL'},
#    'name': 'Cloud Gate',
#    'related_places': {'parent': {'fsq_id': '42b75880f964a52090251fe3',
#      'name': 'Millennium Park'},
#     'children': []},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '4c47533649fa9521cb1f5e62',
#    'categories': [{'id': 16037,
#      'name': 'Playground',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#       'suffix': '.png'}},
#     {'id': 16039,
#      'name': 'Urban Park',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 803,
#    'geocodes': {'main': {'latitude': 41.875734, 'longitude': -87.619047},
#     'roof': {'latitude': 41.875734, 'longitude': -87.619047}},
#    'link': '/v3/places/4c47533649fa9521cb1f5e62',
#    'location': {'address': '337 E Randolph Dr',
#     'census_block': '170313204001022',
#     'country': 'US',
#     'cross_street': 'at Michigan Ave',
#     'dma': 'Chicago',
#     'formatted_address': '337 E Randolph Dr (at Michigan Ave), Chicago, IL 60601',
#     'locality': 'Chicago',
#     'postcode': '60601',
#     'region': 'IL'},
#    'name': 'Grant Park',
#    'related_places': {'children': [{'fsq_id': '5abc1fd497cf5a3a555fa5dc',
#       'name': "South President's Court"},
#      {'fsq_id': '51ed811f498e0dd73fcdf90c', 'name': 'Sir Georg Solti Garden'},
#      {'fsq_id': '536d4622498ef89be313c494', 'name': "North President's Court"},
#      {'fsq_id': '5968d904a9e40229593ea4eb', 'name': 'Formal Gardens'},
#      {'fsq_id': '50b69e52e4b023feffc3b3ae', 'name': 'Maggie Daley Park'},
#      {'fsq_id': '4aba79eef964a5207b8120e3',
#       'name': 'Clarence F. Buckingham Memorial Fountain'},
#      {'fsq_id': '59c41a9c0531e84507afe097', 'name': 'The Muse Statue'},
#      {'fsq_id': '4bc7af152f94d13adf76127f', 'name': 'Agora'},
#      {'fsq_id': '42b75880f964a52090251fe3', 'name': 'Millennium Park'},
#      {'fsq_id': '4a0e2513f964a520cb751fe3',
#       'name': 'Grant Park - Butler Field'},
#      {'fsq_id': '5573339b498eedcba9d7e357', 'name': 'North Rose Garden'},
#      {'fsq_id': '4b157f42f964a520b5ad23e3', 'name': 'Grant Bark Park'},
#      {'fsq_id': '4c42da24cc410f475c65ad61', 'name': 'Congress Plaza'},
#      {'fsq_id': '4c5da00ad25320a1627ec67a', 'name': 'Hutchinson Field'}]},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '42b75880f964a52090251fe3',
#    'categories': [{'id': 10039,
#      'name': 'Music Venue',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 835,
#    'geocodes': {'main': {'latitude': 41.882885, 'longitude': -87.621997},
#     'roof': {'latitude': 41.882885, 'longitude': -87.621997}},
#    'link': '/v3/places/42b75880f964a52090251fe3',
#    'location': {'address': '201 E Randolph St',
#     'census_block': '170313201022014',
#     'country': 'US',
#     'cross_street': 'btwn Columbus Dr & Michigan Ave',
#     'dma': 'Chicago',
#     'formatted_address': '201 E Randolph St (btwn Columbus Dr & Michigan Ave), Chicago, IL 60601',
#     'locality': 'Chicago',
#     'postcode': '60601',
#     'region': 'IL'},
#    'name': 'Millennium Park',
#    'related_places': {'parent': {'fsq_id': '4c47533649fa9521cb1f5e62',
#      'name': 'Grant Park'},
#     'children': [{'fsq_id': '4a461376f964a52085a81fe3',
#       'name': 'Jay Pritzker Pavilion'},
#      {'fsq_id': '4bd1c0c841b9ef3b0f79fce5', 'name': 'Lurie Garden'},
#      {'fsq_id': '4bb4e0106ebfc9b63189edfa',
#       'name': 'Millennium Lakeside Garage'},
#      {'fsq_id': '4ba8ff11f964a520cb013ae3', 'name': 'Crown Fountain'},
#      {'fsq_id': '4e0399f4e4cd92cb899aca0d', 'name': 'Exelon Pavilion'},
#      {'fsq_id': '4ded2fb418385379de3f0e25',
#       'name': 'Chase Promenade Millennium Park'},
#      {'fsq_id': '4bddd17c587b2d7f97345509', 'name': 'BP Bridge'},
#      {'fsq_id': '50ec4163e4b0a40453c39674', 'name': 'Great Lawn'},
#      {'fsq_id': '4bc0e55eb492d13a461ea560', 'name': 'The Nichols Bridgeway'},
#      {'fsq_id': '4bd1c99a77b29c74a4378d82', 'name': 'Wrigley Square'},
#      {'fsq_id': '4e5edf2ee4cdfc603ee1e24d', 'name': 'McCormick Tribune Plaza'},
#      {'fsq_id': '4b021e6ef964a520da4722e3',
#       'name': 'Music and Dance Theater Chicago'},
#      {'fsq_id': '4dc82973c65b89d3caafd826', 'name': 'Boeing Galleries'},
#      {'fsq_id': '4b0850dff964a520da0823e3', 'name': 'Cloud Gate'},
#      {'fsq_id': '50428ae3e4b09c6ce4f61aef',
#       'name': 'Millennium Monument in Wrigley Square'},
#      {'fsq_id': '4f4b989cd5fb493bfa5e9f42', 'name': "McDonald's Cycle Center"},
#      {'fsq_id': '53b3427c498ef9a1b44ce616',
#       'name': 'Millennium Park Summer Film Series'},
#      {'fsq_id': '4582cc9ef964a520843f1fe3',
#       'name': 'Park Grill at Millennium Park'}]},
#    'timezone': 'America/Chicago'},
#   {'fsq_id': '4a461376f964a52085a81fe3',
#    'categories': [{'id': 10039,
#      'name': 'Music Venue',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'distance': 830,
#    'geocodes': {'main': {'latitude': 41.883254, 'longitude': -87.62176},
#     'roof': {'latitude': 41.883254, 'longitude': -87.62176}},
#    'link': '/v3/places/4a461376f964a52085a81fe3',
#    'location': {'address': '201 E Randolph St',
#     'census_block': '170313201022014',
#     'country': 'US',
#     'cross_street': 'btwn Columbus Dr & Michigan Ave',
#     'dma': 'Chicago',
#     'formatted_address': '201 E Randolph St (btwn Columbus Dr & Michigan Ave), Chicago, IL 60601',
#     'locality': 'Chicago',
#     'postcode': '60601',
#     'region': 'IL'},
#    'name': 'Jay Pritzker Pavilion',
#    'related_places': {'parent': {'fsq_id': '42b75880f964a52090251fe3',
#      'name': 'Millennium Park'},
#     'children': []},
#    'timezone': 'America/Chicago'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 41.8781136,
#      'longitude': -87.6297982},
#     'radius': 22000}}}}

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
import pandas as pd
# Use json_normalize() to convert JSON to DataFrame
dict = foursquare_park
df3 = pd.json_normalize(dict['results']) 
df3
park_Four = pd.DataFrame(df3, columns = ['name','location.formatted_address'])
park_Four
# Out:
#                                            name  \
# 0  Symphony Center (Chicago Symphony Orchestra)
# 1                  The Art Institute of Chicago
# 2                            Auditorium Theatre
# 3                               Iwan Ries & Co.
# 4                       Cadillac Palace Theatre
# 5                  James M. Nederlander Theatre
# 6                                    Cloud Gate
# 7                                    Grant Park
# 8                               Millennium Park
# 9                         Jay Pritzker Pavilion
#
#                           location.formatted_address
# 0  220 S Michigan Ave (btwn Adams & Jackson), Chi...
# 1  111 S Michigan Ave (btwn Monroe St & Jackson D...
# 2  50 E Ida B Wells Dr (Roosevelt University), Ch...
# 3  19 S Wabash Ave (btwn E Madison St & E Monroe ...
# 4  151 W Randolph St (at LaSalle St), Chicago, IL...
# 5  24 W Randolph St (btwn State St & Dearborn St)...
# 6  201 E Randolph St (btwn Randolph St & Monroe D...
# 7  337 E Randolph Dr (at Michigan Ave), Chicago, ...
# 8  201 E Randolph St (btwn Columbus Dr & Michigan...
# 9  201 E Randolph St (btwn Columbus Dr & Michigan...

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
business_id = '4U9kSBLuBDU391x6bxU-YA'
api_key = os.environ["YELP_API_KEY"]
headers = {'Authorization': 'Bearer %s' % api_key}
#Define the end point URL for the milano city bike network
endpoint = 'https://api.yelp.com/v3/businesses/search?radius=1000'
params = {'term':'Bike stations','location':'london'}
req=requests.get(endpoint, params=params, headers=headers)
 # proceed only if the status code is 200
print('The status code is {}'.format(req.status_code)) 
# printing the text from the response 
bike_yelp_details = json.loads(req.text)
bike_yelp_details
# Out:
# The status code is 200
# {'businesses': [{'id': 'u_-9CC5FRg-FiA72hVAZtQ',
#    'alias': 'london-bicycle-tour-co-london',
#    'name': 'London Bicycle Tour Co',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EidwtcDzl7cXZ1IXJkxpkg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/london-bicycle-tour-co-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 19,
#    'categories': [{'alias': 'bikerentals', 'title': 'Bike Rentals'},
#     {'alias': 'biketours', 'title': 'Bike tours'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.4961682, 'longitude': -0.1119967},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '74 Kennington Road',
#     'address2': 'Kennington',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE11 6NL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['74 Kennington Road',
#      'Kennington',
#      'London SE11 6NL',
#      'United Kingdom']},
#    'phone': '+442079286838',
#    'display_phone': '+44 20 7928 6838',
#    'distance': 2486.912955215867}],
#  'total': 1,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
business_id = '4U9kSBLuBDU391x6bxU-YA'
api_key = os.environ["YELP_API_KEY"]
headers = {'Authorization': 'Bearer %s' % api_key}
#Define the end point URL for the milano city bike network
endpoint = 'https://api.yelp.com/v3/businesses/search'
params = {'term':'Restaurants','location':'London'}
req=requests.get(endpoint, params=params, headers=headers)
 # proceed only if the status code is 200
print('The status code is {}'.format(req.status_code)) 
# printing the text from the response 
restuarnt_details = json.loads(req.text)
restuarnt_details
# Out:
# The status code is 200
# {'businesses': [{'id': 'Vaq49W0ubGjuIc4h5_qQ0w',
#    'alias': 'the-mayfair-chippy-london-2',
#    'name': 'The Mayfair Chippy',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BDTRkfVSJ8hoAT0amAfwkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-mayfair-chippy-london-2?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 395,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5131345, 'longitude': -0.1533961},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '14 North Audley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1K 6WE',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['14 North Audley Street',
#      'London W1K 6WE',
#      'United Kingdom']},
#    'phone': '+442077412233',
#    'display_phone': '+44 20 7741 2233',
#    'distance': 1205.5379325772763},
#   {'id': 'oK_SLmmAVQg3meguh7LrIA',
#    'alias': 'dishoom-london',
#    'name': 'Dishoom',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LVjieHU8Rah9arssRqP47g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dishoom-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 2277,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.512447030091, 'longitude': -0.1269579217873},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "12 Upper Saint Martin's Lane",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9FB',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["12 Upper Saint Martin's Lane",
#      'London WC2H 9FB',
#      'United Kingdom']},
#    'phone': '+442074209320',
#    'display_phone': '+44 20 7420 9320',
#    'distance': 626.5674318297622},
#   {'id': 'qhbCUUn1CM27dvTPUwvAUA',
#    'alias': 'flat-iron-london-2',
#    'name': 'Flat Iron',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BawTx5b2LdfMVHfFDJUMzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flat-iron-london-2?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 455,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51212, 'longitude': -0.1384008},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '17 Beak Street',
#     'address2': 'Soho',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 9RW',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['17 Beak Street',
#      'Soho',
#      'London W1F 9RW',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 186.27203865325515},
#   {'id': 'teXPunKtpwj0NuttvPYhyQ',
#    'alias': 'the-victoria-paddington',
#    'name': 'The Victoria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fXueWoi1k3Tztueo3wnN4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-victoria-paddington?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 263,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.51350403679, 'longitude': -0.17119959969309},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '10a Strathearn Place',
#     'address2': '',
#     'address3': '',
#     'city': 'Paddington',
#     'zip_code': 'W2 2NH',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['10a Strathearn Place',
#      'Paddington W2 2NH',
#      'United Kingdom']},
#    'phone': '+442077241191',
#    'display_phone': '+44 20 7724 1191',
#    'distance': 2438.1572439509278},
#   {'id': 'L4QlWFPlkJVwDm5_jxt4og',
#    'alias': 'mercato-mayfair-london',
#    'name': 'Mercato Mayfair',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cRYYSmVQlFt5Jp7DmIkPxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mercato-mayfair-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 20,
#    'categories': [{'alias': 'popuprestaurants',
#      'title': 'Pop-Up Restaurants'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5130980394816,
#     'longitude': -0.153270626983613},
#    'transactions': [],
#    'location': {'address1': 'North Audley Street',
#     'address2': '',
#     'address3': "St Mark's Mayfair",
#     'city': 'London',
#     'zip_code': 'W1K 6WL',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['North Audley Street',
#      "St Mark's Mayfair",
#      'London W1K 6WL',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1196.789048537776},
#   {'id': 'Wjgxl0lSp_FRtzecbJ4FZQ',
#    'alias': 'the-queens-arms-london',
#    'name': 'The Queens Arms',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-aZQ5ixyWyZxTIiSSgYPfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-queens-arms-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 164,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.4925789, 'longitude': -0.1392194},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '11 Warwick Way',
#     'address2': 'Pimlico',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1V 1QT',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Warwick Way',
#      'Pimlico',
#      'London SW1V 1QT',
#      'United Kingdom']},
#    'phone': '+442078343313',
#    'display_phone': '+44 20 7834 3313',
#    'distance': 2271.0625715098713},
#   {'id': 'IBV7BsXnv2gX68nWUARhjw',
#    'alias': 'mother-mash-london',
#    'name': 'Mother Mash',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oOiLc_8eHgI2ouwzonR5yg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mother-mash-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 510,
#    'categories': [{'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.512935, 'longitude': -0.139414},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '26 Ganton Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 7QZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['26 Ganton Street',
#      'London W1F 7QZ',
#      'United Kingdom']},
#    'phone': '+442074949644',
#    'display_phone': '+44 20 7494 9644',
#    'distance': 233.42239569404654},
#   {'id': 'hOLFwKg4-0FsCleJ4yoCXw',
#    'alias': 'duck-and-waffle-london',
#    'name': 'Duck & Waffle',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4uCfQ0ZnRnGa9cK9-LpX3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duck-and-waffle-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 841,
#    'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.516178, 'longitude': -0.08094},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '110 Bishopsgate',
#     'address2': '40th Floor',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC2N 4AY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['110 Bishopsgate',
#      '40th Floor',
#      'London EC2N 4AY',
#      'United Kingdom']},
#    'phone': '+442036407310',
#    'display_phone': '+44 20 3640 7310',
#    'distance': 3825.569046751585},
#   {'id': 'tYynO1nOy1GKxMV3jkxbmw',
#    'alias': 'the-breakfast-club-london-2',
#    'name': 'The Breakfast Club',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TElKM303HWt3LAkvgBuTWg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-breakfast-club-london-2?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 551,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.514733, 'longitude': -0.135406},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': "33 D'Arblay Street",
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1F 8EU',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ["33 D'Arblay Street",
#      'London W1F 8EU',
#      'United Kingdom']},
#    'phone': '+442074342571',
#    'display_phone': '+44 20 7434 2571',
#    'distance': 202.48528573555356},
#   {'id': 'KzYd2EaFvmu63wqTIektSA',
#    'alias': 'padella-london-3',
#    'name': 'Padella',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7Nzmy6o_KwF0nLM41S_kUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/padella-london-3?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 272,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5051451, 'longitude': -0.0899515},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 Southwark Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SE1 1TQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 Southwark Street',
#      'London SE1 1TQ',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3306.1684522874934},
#   {'id': 'lg0ZQJDQeHN_5Ela7ypyiw',
#    'alias': 'the-golden-chippy-london',
#    'name': 'The Golden Chippy',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bkFPTIbhVCB1LzlwmCwXzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-golden-chippy-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 141,
#    'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 51.475864, 'longitude': -0.018518},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '62 Greenwich High Road',
#     'address2': 'Greenwich',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'SE10 8LF',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['62 Greenwich High Road',
#      'Greenwich',
#      'London SE10 8LF',
#      'United Kingdom']},
#    'phone': '+442086924333',
#    'display_phone': '+44 20 8692 4333',
#    'distance': 9116.786047289621},
#   {'id': 'zJNI06Y2zZQFh9OBSFCdgQ',
#    'alias': 'sketch-london-2',
#    'name': 'Sketch',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jE0K_IohFjyvVnVY2EdFlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sketch-london-2?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 955,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'modern_european', 'title': 'Modern European'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.5127614699071,
#     'longitude': -0.14159163911048},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '9 Conduit Street',
#     'address2': 'Mayfair',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1S 2XG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['9 Conduit Street',
#      'Mayfair',
#      'London W1S 2XG',
#      'United Kingdom']},
#    'phone': '+442076594500',
#    'display_phone': '+44 20 7659 4500',
#    'distance': 388.9437191578902},
#   {'id': 'Rb3xF0gkAwnDHML6okB1FA',
#    'alias': 'honey-and-co-london',
#    'name': 'Honey & Co',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GjRuBFxsvAvRsNXS44S23Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/honey-and-co-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 117,
#    'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5238287, 'longitude': -0.1407882},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '25a Warren Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1T 5LZ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['25a Warren Street',
#      'London W1T 5LZ',
#      'United Kingdom']},
#    'phone': '+442073886175',
#    'display_phone': '+44 20 7388 6175',
#    'distance': 1256.142106360687},
#   {'id': 'bJiVADMSTEKj0MjqiLrOPA',
#    'alias': 'the-grazing-goat-marylebone-london',
#    'name': 'The Grazing Goat Marylebone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/h73f5PAFit9wdm8w_zm3lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-grazing-goat-marylebone-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 274,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.515378341447,
#     'longitude': -0.15823586449841},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '6 New Quebec Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1H 7RQ',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['6 New Quebec Street',
#      'London W1H 7RQ',
#      'United Kingdom']},
#    'phone': '+442077247243',
#    'display_phone': '+44 20 7724 7243',
#    'distance': 1563.9775349708373},
#   {'id': 'b8u_D0Qlp0-nqSC6O2fMNw',
#    'alias': 'restaurant-gordon-ramsay-london-3',
#    'name': 'Restaurant Gordon Ramsay',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aF5kqFsGNKZm1M2BSXkMZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/restaurant-gordon-ramsay-london-3?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 237,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.485833, 'longitude': -0.161966},
#    'transactions': [],
#    'price': '££££',
#    'location': {'address1': '68 Royal Hospital Road',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW3 4HP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['68 Royal Hospital Road',
#      'London SW3 4HP',
#      'United Kingdom']},
#    'phone': '+442073524441',
#    'display_phone': '+44 20 7352 4441',
#    'distance': 3509.7496283842606},
#   {'id': '0B-ag3J18TatG9H9EQohGg',
#    'alias': 'hawksmoor-seven-dials-london-4',
#    'name': 'Hawksmoor Seven Dials',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lbFKecn94lG2Vd4UPeFYEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hawksmoor-seven-dials-london-4?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 377,
#    'categories': [{'alias': 'british', 'title': 'British'},
#     {'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5134998914001,
#     'longitude': -0.12567396291297},
#    'transactions': [],
#    'price': '£££',
#    'location': {'address1': '11 Langley Street',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'WC2H 9JG',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['11 Langley Street',
#      'London WC2H 9JG',
#      'United Kingdom']},
#    'phone': '+442074209390',
#    'display_phone': '+44 20 7420 9390',
#    'distance': 715.8050107104362},
#   {'id': 'mc1KLbA1Sy4kUTKo0ZEeRQ',
#    'alias': 'dishoom-london-7',
#    'name': 'Dishoom',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bnu8b8OxipYI_mNA0a5_PQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dishoom-london-7?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 646,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.513087, 'longitude': -0.139767},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '22 Kingly Street',
#     'address2': None,
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'W1B 5QP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['22 Kingly Street',
#      'London W1B 5QP',
#      'United Kingdom']},
#    'phone': '+442074209322',
#    'display_phone': '+44 20 7420 9322',
#    'distance': 262.7329356516094},
#   {'id': 'Z0r83lDOA1mI8RpNccXtHw',
#    'alias': 'the-fat-bear-london',
#    'name': 'The Fat Bear',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2ac6nNGBviKDuYYukDRmRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-fat-bear-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 127,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'soulfood', 'title': 'Soul Food'},
#     {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5131833881734,
#     'longitude': -0.10138103121642},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '61 Carter Lane',
#     'address2': '',
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'EC4V 5DY',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['61 Carter Lane',
#      'London EC4V 5DY',
#      'United Kingdom']},
#    'phone': '+442072362498',
#    'display_phone': '+44 20 7236 2498',
#    'distance': 2394.295553294889},
#   {'id': '1bR581OwoAOLMLG9sS_tow',
#    'alias': 'circolo-popolare-london',
#    'name': 'Circolo Popolare',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zCKcIxCRYEz-0ZkL_OFSoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/circolo-popolare-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 54,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 51.51734, 'longitude': -0.13408},
#    'transactions': [],
#    'location': {'address1': '40-41 Rathbone Place',
#     'address2': '',
#     'address3': None,
#     'city': 'London',
#     'zip_code': 'W1T 1HX',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['40-41 Rathbone Place',
#      'London W1T 1HX',
#      'United Kingdom']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 497.34406976788006},
#   {'id': 'a4FkZ2b7Wn3-AP7q3ptHtQ',
#    'alias': 'duck-and-waffle-local-london',
#    'name': 'Duck & Waffle Local',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1x4I2Yy_waGhbs8MKn_KUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duck-and-waffle-local-london?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 146,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'waffles', 'title': 'Waffles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 51.5094175706263,
#     'longitude': -0.132749820495633},
#    'transactions': [],
#    'price': '££',
#    'location': {'address1': '52 Haymarket',
#     'address2': "St James's Market",
#     'address3': '',
#     'city': 'London',
#     'zip_code': 'SW1Y 4RP',
#     'country': 'GB',
#     'state': 'XGL',
#     'display_address': ['52 Haymarket',
#      "St James's Market",
#      'London SW1Y 4RP',
#      'United Kingdom']},
#    'phone': '+442039004444',
#    'display_phone': '+44 20 3900 4444',
#    'distance': 450.4935927796803}],
#  'total': 13300,
#  'region': {'center': {'longitude': -0.135955810546875,
#    'latitude': 51.51283552118349}}}

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# Use json_normalize() to convert JSON to DataFrame
dict = restuarnt_details
df2 = pd.json_normalize(dict['businesses']) 
df2
restaurant_data = pd.DataFrame(df2, columns = ['name','review_count','location.address1','rating'])
restaurant_data
# Out:
#                            name  review_count             location.address1  \
# 0            The Mayfair Chippy           395        14 North Audley Street
# 1                       Dishoom          2277  12 Upper Saint Martin's Lane
# 2                     Flat Iron           455                17 Beak Street
# 3                  The Victoria           263          10a Strathearn Place
# 4               Mercato Mayfair            20           North Audley Street
# 5               The Queens Arms           164                11 Warwick Way
# 6                   Mother Mash           510              26 Ganton Street
# 7                 Duck & Waffle           841               110 Bishopsgate
# 8            The Breakfast Club           551            33 D'Arblay Street
# 9                       Padella           272            6 Southwark Street
# 10            The Golden Chippy           141        62 Greenwich High Road
# 11                       Sketch           955              9 Conduit Street
# 12                   Honey & Co           117             25a Warren Street
# 13  The Grazing Goat Marylebone           274           6 New Quebec Street
# 14     Restaurant Gordon Ramsay           237        68 Royal Hospital Road
# 15        Hawksmoor Seven Dials           377             11 Langley Street
# 16                      Dishoom           646              22 Kingly Street
# 17                 The Fat Bear           127                61 Carter Lane
# 18             Circolo Popolare            54          40-41 Rathbone Place
# 19          Duck & Waffle Local           146                  52 Haymarket
#
#     rating
# 0      4.5
# 1      4.5
# 2      4.5
# 3      4.5
# 4      4.5
# 5      4.5
# 6      4.0
# 7      4.0
# 8      4.0
# 9      4.5
# 10     5.0
# 11     4.0
# 12     4.5
# 13     4.0
# 14     4.5
# 15     4.5
# 16     4.5
# 17     4.5
# 18     4.0
# 19     4.5

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# yelp api provided more complete data compare to foursquare api.
# it is provide rating,reviews details and many more compare to foursquare api

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
data = restaurant_data.sort_values(by = ['rating'], ascending = [False])

# %%
data.head(10)
# Out:
#                      name  review_count             location.address1  rating
# 10      The Golden Chippy           141        62 Greenwich High Road     5.0
# 16            The Barbary            87                16 Neal's Yard     5.0
# 8   Hawksmoor Seven Dials           376             11 Langley Street     4.5
# 17                Dishoom           645              22 Kingly Street     4.5
# 15                   Kiln            69              58 Brewer Street     4.5
# 13             Honey & Co           117             25a Warren Street     4.5
# 1                 Dishoom          2276  12 Upper Saint Martin's Lane     4.5
# 0      The Mayfair Chippy           394        14 North Audley Street     4.5
# 6                 Padella           272            6 Southwark Street     4.5
# 5         The Queens Arms           163                11 Warwick Way     4.5
