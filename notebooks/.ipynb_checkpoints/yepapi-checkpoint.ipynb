# %% [markdown]
# # Parrt :2 Yelp api parsing

# %%
import requests
import json

# %%
business_id = '4U9kSBLuBDU391x6bxU-YA'

# %%
api_key="XePiQ9fpzbAICkINnPTCw13JesoFIXfC-Em_4wRqITzPC94s2TL7iFP_tjV6Fw9FkbZRllKUhsqxjcuyQ7bVQiLaud6i9ZeZMJh-r7cm4eU9AF4At-iPuWx1ZVZDZHYx"
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
#Define the end point URL for the milano city bike network
endpoint = 'https://api.yelp.com/v3/businesses/search'

# %%
params = {'term':'Restaurants','location':'New York City'}

# %%
req=requests.get(endpoint, params=params, headers=headers)
 # proceed only if the status code is 200
print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
# printing the text from the response 
restuarnt_details = json.loads(req.text)

# %%
restuarnt_details
# Out:
# {'businesses': [{'id': 'hdiuRS9sVZSMReZm4oV5SA',
#    'alias': 'da-andrea-new-york',
#    'name': 'Da Andrea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OciLddTWxvBLKMH5DkMAOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-andrea-new-york?adjust_creative=fTSM8xnDvU99-EqonN-pgw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=fTSM8xnDvU99-EqonN-pgw',
#    'review_count': 1882,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.736218, 'longitude': -73.99597},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '35 W 13th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
# ...

# %%
import pandas as pd

# %%
#flatten data 
#df_nested_list = pd.json_normalize(restaurant_data, record_path = ['businesses'])

#Use df.set_axis() to rename columns permanently using "inplace=true"
#df2 = df_nested_list.set_axis(['alias', 'name'], axis=1, inplace=True)
#print(df_nested_list)

# %%
# Use json_normalize() to convert JSON to DataFrame
dict = restuarnt_details
df2 = pd.json_normalize(dict['businesses'])

# %%
df2
# Out:
#                         id                              alias  \
# 0   hdiuRS9sVZSMReZm4oV5SA                 da-andrea-new-york
# 1   8YWLuLUKj0t_0_Xv06UUtw          yes-apothecary-new-york-4
# 2   WG639VkTjmK5dzydd1BBJA                rubirosa-new-york-2
# 3   Me4TxTbPPQZQopW1wOGx5g          jacks-wife-freda-new-york
# 4   axqp3pGJXnTLgq2QrPyDyQ                   benemon-new-york
# 5   MGd6HFEq1ALD58XWNviSXw  time-out-market-new-york-brooklyn
# 6   WJS06XxRdc6DD1s4LWE9HA               fish-cheeks-new-york
# 7   FlZ1zdVEKWv7dwqm8Uw8-w                    raku-new-york-7
# 8   nMyot99PkX5iYCdxHoRJqQ                    ariari-new-york
# 9   qEe7nIhPfEL6L0-VYhWRrA                    raku-new-york-6
# 10  5F9kZPnAleDYqCeCyvGJPA                 bad-roman-new-york
# 11  6GAB0Rn6eBqCUO9Tx9BNgQ                     bōm-new-york-3
# 12  i-HGZmxvw-4PwSNO4uumpg               rice-thief-sunnyside
# 13  LpVbI-E9C-CSp7WhU5h2Iw     fishmarket-restaurant-new-york
# ...

# %%
restaurant_data = pd.DataFrame(df2, columns = ['name','location.address1','review_count','rating'])

# %%
restaurant_data
# Out:
#                         name location.address1  review_count  rating
# 0                  Da Andrea      35 W 13th St          1882     4.5
# 1            Ye's Apothecary    119 Orchard St           236     4.5
# 2                   Rubirosa   235 Mulberry St          2973     4.5
# 3          Jack's Wife Freda  226 Lafayette St          2327     4.0
# 4                    Benemon      108 E 4th St           701     4.5
# 5   Time Out Market New York       55 Water St           470     4.0
# 6                Fish Cheeks        55 Bond St          1264     4.5
# 7                       Raku      342 E 6th St          1505     4.5
# 8                     ARIARI       119 1st Ave           104     4.5
# 9                       Raku   48 Macdougal St           836     4.5
# 10                 Bad Roman   10 Columbus Cir            93     4.0
# 11                       bōm      17 W 19th St             2     5.0
# 12                Rice Thief                              11     4.5
# ...
